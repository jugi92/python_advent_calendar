# %% [markdown]
# Even during the crisis flight radar visualizes severall flights and it looks as if the earth surface is largely covered by planes
# ![image.png](attachment:478da231-79ad-4fed-8749-ae46b01731d3.png)

# %% [markdown]
# Lets try to create an understanding of how much of the surface of the earth is actually covered by aircrafts.

# %%
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', 500)

# %% [markdown]
# We will use the opensky aircraft database to get a huge list of aircrafts (might be non exhaustive, but we are going for an approximation here).

# %%
df = pd.read_csv("https://opensky-network.org/datasets/metadata/aircraftDatabase.csv", low_memory=False)

# %%
df
# Out:
#         icao24 registration  manufacturericao               manufacturername  \
# 0          NaN          NaN               NaN                            NaN
# 1       aa3487        N757F               NaN      Raytheon Aircraft Company
# 2       ae267b         6533            VOUGHT                   Aerospatiale
# 3       a4fa61        N42MH               NaN                          Piper
# 4       c04101       C-FYQA               NaN  Champion Aircraft Corporation
# ...        ...          ...               ...                            ...
# 459995  c0a0d5       C-IIXO               NaN               Patrick Gilligan
# 459996  a8d953       N6699Z               NaN              Vans Aircraft Inc
# 459997  a638ba        N50MR               NaN                  Ludtke Edward
# 459998  4aaa55       SE-JRU               LOT             Airbus Helicopters
# 459999  3e7099       D-KHVL  VICKERS-SLINGSBY                        Scheibe
#
# ...

# %%
df.registration.describe()
# Out:
# count     422723
# unique    422260
# top         5XXX
# freq          35
# Name: registration, dtype: object

# %%
# https://en.wikipedia.org/wiki/Earth
# Earth Surface in Square Kilometer
earthsqkm = 510072000

# %%
# A380 values in Meter
wingspan = 80
length = 73

# %% [markdown]
# Lets compute the percentage of the earth that is cover by planes (only those that have a registration)
# We will asume all planes have the values of A380s and they cover a rhombus aka Diamond shape with their length and wingspan as diagonals.
# As we already now that it will be a small ratio, try to visualize it to better understand it.

# %%
# write your code here

# %%
coveredArea / 1000000
# Out:
# 1234.35116

# %% [markdown]
# So it seems all planes densily parked next to each other would cover the area of the Faroe Islands: https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area
